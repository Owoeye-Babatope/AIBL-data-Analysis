# %% [markdown]
# <a href="https://colab.research.google.com/github/Owoeye-Babatope/AIBL-data-Analysis/blob/main/Overview_of_Colaboratory_Features.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # COM 737
# A notebook is a list of cells. Cells contain either explanatory text or executable code and its output. Click a cell to select it.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

dataID = pd.read_csv('DATADIC(1).csv')
Apoe = pd.read_csv("aibl_apoeres_01-Jun-2018.csv")
CDR = pd.read_csv("aibl_cdr_01-Jun-2018.csv")
Bloodtest = pd.read_csv("aibl_labdata_01-Jun-2018.csv")
Medical_History = pd.read_csv("aibl_medhist_01-Jun-2018.csv")
MMSE_Score = pd.read_csv("aibl_mmse_01-Jun-2018.csv")
LMR_Score = pd.read_csv("aibl_neurobat_01-Jun-2018.csv")


merged = pd.merge(Apoe, CDR, how='outer', left_on='RID', right_on='RID')
merged = pd.merge(merged, Bloodtest, how='outer', left_on='RID', right_on='RID')
merged = pd.merge(merged, Medical_History, how='outer', left_on='RID', right_on='RID')
merged = pd.merge(merged, MMSE_Score, how='outer', left_on='RID', right_on='RID')
merged = pd.merge(merged, LMR_Score, how='outer', left_on='RID', right_on='RID')
merged.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: FutureWarning: Passing 'suffixes' which cause duplicate columns {'SITEID_x', 'VISCODE_x'} in the result is deprecated and will raise a MergeError in a future version.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: FutureWarning: Passing 'suffixes' which cause duplicate columns {'SITEID_x', 'VISCODE_x'} in the result is deprecated and will raise a MergeError in a future version.
# (77216, 45)

# %% [markdown]
# # New Section

# %%
flit = (merged.iloc[:, 2] == 'bl')
bl = merged[flit]   # 11 and 37
data = bl.drop('VISCODE_x', axis=1)
data
# Out:
#         RID  SITEID_x    APTESTDT  APGEN1  APGEN2  SITEID_y  VISCODE_y  \
# 0         2         1  09/16/2011       3       3         1         bl
# 1         2         1  09/16/2011       3       3         1         bl
# 2         2         1  09/16/2011       3       3         1         bl
# 3         2         1  09/16/2011       3       3         1         bl
# 4         2         1  09/16/2011       3       3         1         bl
# ...     ...       ...         ...     ...     ...       ...        ...
# 77211  1632         2  07/11/2014      -4      -4         2         bl
# 77212  1634         2  07/15/2014      -4      -4         2         bl
# 77213  1636         2  07/21/2014      -4      -4         2         bl
# 77214  1637         2  07/24/2014      -4      -4         2         bl
# 77215  1639         2  07/28/2014      -4      -4         2         bl
#
#        EXAMDATE_x  CDGLOBAL  SITEID_x  ...  MH16SMOK  MH17MALI  SITEID_x  \
# 0      09/16/2011       0.0         1  ...        -4         0         1
# 1      09/16/2011       0.0         1  ...        -4         0         1
# 2      09/16/2011       0.0         1  ...        -4         0         1
# 3      09/16/2011       0.0         1  ...        -4         0         1
# 4      09/16/2011       0.0         1  ...        -4         0         1
# ...           ...       ...       ...  ...       ...       ...       ...
# 77211  07/11/2014       0.5         2  ...         1         0         2
# 77212  07/15/2014      -4.0         2  ...         1         0         2
# 77213  07/21/2014       0.5         2  ...         1         0         2
# 77214  07/24/2014       0.5         2  ...         0         0         2
# 77215  07/28/2014       0.0         2  ...         1         0         2
#
#        EXAMDATE_y  MMSCORE  SITEID_y  VISCODE_y    EXAMDATE  LIMMTOTAL  \
# 0      09/16/2011       30         1         bl  09/16/2011         16
# 1      09/16/2011       30         1        m18  04/11/2013         14
# 2      04/11/2013       30         1         bl  09/16/2011         16
# 3      04/11/2013       30         1        m18  04/11/2013         14
# 4      09/16/2011       30         1         bl  09/16/2011         16
# ...           ...      ...       ...        ...         ...        ...
# 77211  07/11/2014       27         2         bl  07/11/2014          6
# 77212  07/15/2014       20         2         bl  07/15/2014          5
# 77213  07/21/2014       28         2         bl  07/21/2014          3
# 77214  07/24/2014       28         2         bl  07/24/2014          8
# 77215  07/28/2014       27         2         bl  07/28/2014          8
#
#        LDELTOTAL
# 0             14
# 1             15
# 2             14
# 3             15
# 4             14
# ...          ...
# 77211          6
# 77212          4
# 77213          3
# 77214         12
# 77215          7
#
# [77216 rows x 42 columns]
